# %%
import os
import import_ipynb
import Connections as conn
import cx_Oracle
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json
import time
import datetime
# Out:
# importing Jupyter notebook from Connections.ipynb

# %%
psl_matches_df = pd.read_csv(r'C:/Users/ninju/OneDrive/Desktop/Cricket_Analysis/Cricsheet data/PSL_Input_Folder/all_matches.csv')
psl_matches_df
# Out:
#        match_id   season  start_date                                venue  \
# 0       1075986  2016/17  2017-02-09  Dubai International Cricket Stadium
# 1       1075986  2016/17  2017-02-09  Dubai International Cricket Stadium
# 2       1075986  2016/17  2017-02-09  Dubai International Cricket Stadium
# 3       1075986  2016/17  2017-02-09  Dubai International Cricket Stadium
# 4       1075986  2016/17  2017-02-09  Dubai International Cricket Stadium
# ...         ...      ...         ...                                  ...
# 37106   1247024  2020/21  2021-03-03                     National Stadium
# 37107   1247024  2020/21  2021-03-03                     National Stadium
# 37108   1247024  2020/21  2021-03-03                     National Stadium
# 37109   1247024  2020/21  2021-03-03                     National Stadium
# 37110   1247024  2020/21  2021-03-03                     National Stadium
#
#        innings  ball    batting_team       bowling_team          striker  \
# ...
